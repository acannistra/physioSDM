# %%
library(dplyr)
library(jsonlite)
library(ggplot2)
library(raster)
library(tidyr)
options(warn=-1)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# Loading required package: sp
#
# Attaching package: ‘raster’
#
# The following object is masked from ‘package:dplyr’:
#
#     select
#
#
# Attaching package: ‘tidyr’
#
# The following object is masked from ‘package:raster’:
#
#     extract

# %% [markdown]
# # R SDM Processing Pipeline
#
# Here we present the pipeline for acquiring and processing occurrence and climate data for the purposes of species distribution modeling. We presume single species GBIF point observations and raster climate data of varying timescales. Past work has included BIOCLIM and other aggregate climatological metrics.
#
# ## 1. Process Occurrence Data
#
# To bypass the challenges of programmatiically downloading large quantities of GBIF data, we've extracted the data manually using GBIF's [occurrence search portal](http://www.gbif.org/species) to download all available occurences within a specified geographic bounding box, which was acquired [here](boundingbox.klokantech.com).
#
# We first load parameters for this experiment, then load the necessary occurrence files.

# %%
parameters = fromJSON('../parameters.json')
parameters
# Out:
# $species
# [1] "sceloporus occidentalis"
#
# $occdata
# [1] "/Users/tony/Dropbox/Projects/UW/physdm/data/occs/sceloporus_occidentalis_westus.csv"
#
# $bbox
# [1] -124.49733   31.01667 -105.00700   48.33540
#
# $time_periods
# [1] "1900:1939" "1970:2009"

# %%
occurrences = read.csv(parameters$occdata, sep='\t')
head(occurrences)
# Out:
#   gbifid     datasetkey
# 1 1562985257 50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 2 1562985245 50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 3 1562985190 50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 4 1562985170 50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 5 1562985061 50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 6 1562985049 50c9509d-22c7-4a22-a47d-8c48425ef4a7
#   occurrenceid                                   kingdom  phylum   class
# 1 http://www.inaturalist.org/observations/894194 Animalia Chordata Reptilia
# 2 http://www.inaturalist.org/observations/886454 Animalia Chordata Reptilia
# 3 http://www.inaturalist.org/observations/851281 Animalia Chordata Reptilia
# 4 http://www.inaturalist.org/observations/839234 Animalia Chordata Reptilia
# 5 http://www.inaturalist.org/observations/775932 Animalia Chordata Reptilia
# 6 http://www.inaturalist.org/observations/771173 Animalia Chordata Reptilia
#   order    family          genus      species                 ⋯ recordnumber
# 1 Squamata Phrynosomatidae Sceloporus Sceloporus occidentalis ⋯
# 2 Squamata Phrynosomatidae Sceloporus Sceloporus occidentalis ⋯
# 3 Squamata Phrynosomatidae Sceloporus Sceloporus occidentalis ⋯
# 4 Squamata Phrynosomatidae Sceloporus Sceloporus occidentalis ⋯
# 5 Squamata Phrynosomatidae Sceloporus Sceloporus occidentalis ⋯
# 6 Squamata Phrynosomatidae Sceloporus Sceloporus occidentalis ⋯
#   identifiedby license      rightsholder recordedby   typestatus
# 1              CC_BY_NC_4_0 James Maughn James Maughn
# 2              CC_BY_NC_4_0 James Maughn James Maughn
# 3              CC_BY_NC_4_0 James Maughn James Maughn
# 4              CC_BY_NC_4_0 James Maughn James Maughn
# 5              CC_BY_NC_4_0 James Maughn James Maughn
# 6              CC_BY_NC_4_0 James Maughn James Maughn
#   establishmentmeans lastinterpreted   mediatype
# 1                    2017-05-29T15:20Z
# 2                    2017-05-29T15:20Z
# 3                    2017-05-29T15:20Z
# 4                    2017-05-29T15:20Z
# 5                    2017-05-29T15:20Z
# 6                    2017-05-29T15:20Z
#   issue
# 1 GEODETIC_DATUM_ASSUMED_WGS84;COORDINATE_ROUNDED
# 2 GEODETIC_DATUM_ASSUMED_WGS84;COORDINATE_ROUNDED
# 3 GEODETIC_DATUM_ASSUMED_WGS84;COORDINATE_ROUNDED
# 4 GEODETIC_DATUM_ASSUMED_WGS84;COORDINATE_ROUNDED
# 5 GEODETIC_DATUM_ASSUMED_WGS84;COORDINATE_ROUNDED
# 6 GEODETIC_DATUM_ASSUMED_WGS84;COORDINATE_ROUNDED

# %%
colnames(occurrences)
# Out:
#  [1] "gbifid"                        "datasetkey"
#  [3] "occurrenceid"                  "kingdom"
#  [5] "phylum"                        "class"
#  [7] "order"                         "family"
#  [9] "genus"                         "species"
# [11] "infraspecificepithet"          "taxonrank"
# [13] "scientificname"                "countrycode"
# [15] "locality"                      "publishingorgkey"
# [17] "decimallatitude"               "decimallongitude"
# [19] "coordinateuncertaintyinmeters" "coordinateprecision"
# [21] "elevation"                     "elevationaccuracy"
# [23] "depth"                         "depthaccuracy"
# [25] "eventdate"                     "day"
# [27] "month"                         "year"
# [29] "taxonkey"                      "specieskey"
# [31] "basisofrecord"                 "institutioncode"
# [33] "collectioncode"                "catalognumber"
# [35] "recordnumber"                  "identifiedby"
# [37] "license"                       "rightsholder"
# [39] "recordedby"                    "typestatus"
# [41] "establishmentmeans"            "lastinterpreted"
# [43] "mediatype"                     "issue"

# %%
states = map_data('state')
west = subset(states, region %in% c("california", "oregon", "washington", 'idaho', 'utah', 'colorado', 'texas', 'nevada', 'new mexico'))

ggplot() +
geom_point(data=occurrences, aes(x=decimallongitude, y=decimallatitude), shape=3, color='red') +
geom_polygon(data=west , aes(x = long, y = lat, group=group), fill=NA, color='black') +
coord_fixed(1.3) + 
guides(fill=FALSE)
# Out:
# plot without title

# %%
ggplot(occurrences, aes(year)) + geom_bar() + ggtitle(paste0("Observations of ", parameters$species))
# Out:
# plot without title

# %% [markdown]
# The purpose of this particular experiment is to compare SDM performance across time, which means we need to subset the data. The time periods are in the parameters file:

# %%
period_occs = list()

print(parameters$time_periods)
for (period_idx in seq_along(parameters$time_periods)){
    split = strsplit(parameters$time_periods[period_idx], ":")
    start = as.integer(split[[1]][1])
    end = as.integer(split[[1]][2])
    oc = occurrences %>% filter(year >= start & year <= end)
    period_occs[[period_idx]] = oc
}
# Out:
# [1] "1900:1939" "1970:2009"

# %%
period_occs[[1]] %>% summarise(period = parameters$time_periods[[1]], minyear = min(year), maxyear = max(year))
# Out:
#   period    minyear maxyear
# 1 1900:1939 1900    1939

# %%
period_occs[[2]] %>% summarise(period = parameters$time_periods[[2]], minyear = min(year), maxyear = max(year))
# Out:
#   period    minyear maxyear
# 1 1970:2009 1970    2009

# %% [markdown]
# ## 2. Download Corresponding Climate Data
# Unforunately, for most of the climate data providers, there's not an easy way to get climate information through a web interface. As a result, we're going to rely on the `prism` R package to programmattically download the climate information we need. There are lots of ways to tackle this part of the process, and we're building some tools for that in the future. We're going to save all of the prism data in the default directory, which is `~/prismtmp`. We're also going to keep the `zip` files in case we need to get at the data again.

# %%
library(prism)

# %% [markdown]
# To most effectively use the PRISM library, we need to know the years for which we need climate information. For this particular experiment we're comparing model performance across time. This means we have two chunks of climate data that are needed:

# %%
parameters$time_periods
# Out:
# [1] "1900:1939" "1970:2009"

# %%
period_clim = list()

for (period_idx in seq_along(parameters$time_periods)){
    split = strsplit(parameters$time_periods[period_idx], ":")
    start = as.integer(split[[1]][1])
    end = as.integer(split[[1]][2])
    tmin = prism::get_prism_monthlys('tmin', years=start:end, mon=1:12, keepZip=T)
    period_clim[[period_idx]] = tmin
}
# Out:
# You have not set a path to hold your prism files.

# %% [markdown]
# Noticing above, this code only downloads the `tmin` variable (min temperature) monthly for the time periods in the parameters file. This produces a bunch of files:

# %%
nrow(ls_prism_data())
# Out:
# You have not set a path to hold your prism files.
# Please enter the full or relative path to download files to (hit enter to use default '~/prismtmp'):
# [1] 948

# %% [markdown]
# We can take a look at one of them: `

# %%
prism_image(ls_prism_data()[895,1], col='heat')
# Out:
# plot without title

# %% [markdown]
# The process is identical for `tmax` and `pcp`.

# %% [markdown]
# ## 3. Extracting Climate Data for Each Occurrence
# This portion of the pipeline is easily the most frustrating, and can be computationally intractible for large quantities of data. The hope here is to scale this system to a large number of occurences and to pull from a high-quality multivariate environmental dataset without much trouble, but that requires a significant investment in infrastructure. For now, we'll try to engineer this in a way which is in-memory computable.
#
# Because PRISM files are monthly, we have to subset the occurence information by month, then extract the data that way. Here goes:

# %%
extractPRISMvar <- function(lons, lats, month, year, variable){
    searchstr = sprintf("PRISM_%s_stable_4kmM2_%d%02d", variable, year, month)
    result = (ls_prism_data(absPath = T)[grep(searchstr, ls_prism_data()[,1]),]$abs_path)
    if (length(result) != 1) {
        print("No Results or something is buggy!")
        return(data.frame())
    }
    rast = raster(result)
    points = SpatialPoints(data.frame(lons, lats))
    print(points)
    return(data.frame(raster::extract(rast, points, lons, lats)))
}

# %%
groups = period_occs[[1]] %>%
filter(!is.na(year)) %>% 
filter(!is.na(month)) %>%
group_by(year, month)


ans = groups %>% do(extractPRISMvar(.$decimallongitude, .$decimallatitude, head(.$month,1), head(.$year,1), 'tmin'))
# Out:
# class       : SpatialPoints
# features    : 18
# extent      : -119.2416, -119.2416, 34.44984, 34.44984  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 2
# extent      : -116.5461, -116.5461, 33.06893, 33.06893  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -121.8936, -121.8936, 36.60028, 36.60028  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -119.4597, -119.4597, 37.83086, 37.83086  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 2
# extent      : -121.5497, -121.4957, 36.23238, 36.23378  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 5
# extent      : -121.9778, -116.6117, 36.05199, 39.40355  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 12
# extent      : -120.8557, -120.8113, 39.18067, 39.2065  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -117.1122, -117.1122, 32.73238, 32.73238  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 5
# extent      : -120.3744, -120.3744, 34.03972, 34.03972  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 2
# extent      : -119.8267, -119.8267, 34.43583, 34.43583  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -118.8111, -118.8111, 36.55333, 36.55333  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 2
# extent      : -118.9175, -118.1975, 34.10107, 36.46972  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 2
# extent      : -118.1975, -118.1975, 34.10107, 34.10107  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 4
# extent      : -121.9289, -119.7167, 34.01667, 36.62889  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -118.9175, -118.9175, 36.46972, 36.46972  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -122.4572, -122.4572, 37.71583, 37.71583  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 78
# extent      : -122.8325, -118.8111, 36.22219, 38.08917  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 40
# extent      : -121.9506, -119.9067, 36.53603, 37.21477  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 91
# extent      : -121.9183, -118.7607, 34.81194, 42.82487  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 30
# extent      : -122.2772, -120.5461, 36.49424, 42.69376  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 2
# extent      : -122.465, -122.4494, 37.75667, 37.79722  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 18
# extent      : -119.0175, -118.3602, 34.80948, 36.17779  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 4
# extent      : -118.4992, -117.7154, 33.87281, 34.68232  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 17
# extent      : -121.9218, -116.6114, 31.86363, 37.68445  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 8
# extent      : -121.9218, -118.2016, 34.36666, 37.68445  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -117.907, -117.907, 34.15967, 34.15967  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -122.4692, -122.4692, 38.50528, 38.50528  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -116.8588, -116.8588, 34.36233, 34.36233  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 8
# extent      : -118.2016, -117.1936, 33.04029, 34.36666  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 2
# extent      : -121.9183, -118.3849, 34.08478, 36.555  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 2
# extent      : -121.9289, -118.4053, 34.10428, 36.62889  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 12
# extent      : -118.4053, -117.3129, 34.10428, 34.51036  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 5
# extent      : -122.2268, -118.4053, 34.10428, 37.40808  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 2
# extent      : -122.0731, -105.007, 37.05139, 37.505  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 13
# extent      : -121.9183, -121.9183, 36.555, 36.555  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 15
# extent      : -121.9183, -117.663, 33.5017, 36.61111  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 6
# extent      : -122.3192, -116.719, 33.74, 41.13  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 4
# extent      : -117.1564, -116.6114, 31.86363, 32.71528  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 4
# extent      : -118.0643, -118.0365, 34.16386, 34.16659  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 10
# extent      : -118.0597, -116.4416, 32.64002, 34.69546  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 31
# extent      : -121.9736, -116.4416, 32.60518, 37.22667  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 29
# extent      : -116.8816, -116.4416, 33.54285, 34.69546  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 15
# extent      : -121.521, -116.6006, 33.07001, 45.7054  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 9
# extent      : -118.2016, -116.6312, 33.61222, 34.36666  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 8
# extent      : -117.5036, -116.7106, 33.08, 33.82704  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 4
# extent      : -117.4556, -110.713, 34.03006, 38.373  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 4
# extent      : -122.4942, -116.1896, 32.61802, 37.75833  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 2
# extent      : -122.4494, -122.1692, 37.42722, 37.75667  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 11
# extent      : -121.9188, -118.0469, 34.24537, 41.84397  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 51
# extent      : -121.8708, -116.6006, 33.21, 41.84397  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -122.2378, -122.2378, 37.87429, 37.87429  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -122.2178, -122.2178, 38.34393, 38.34393  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 31
# extent      : -121.7817, -118.0532, 34.162, 42.22487  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 5
# extent      : -122.1692, -122.1043, 37.42722, 37.73226  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -122.2268, -122.2268, 37.40808, 37.40808  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -122.2302, -122.2302, 37.86694, 37.86694  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 3
# extent      : -116.7383, -116.7383, 33.10833, 33.10833  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 31
# extent      : -122.2723, -120.329, 37.86963, 41.79968  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 20
# extent      : -120.5275, -120.329, 41.43619, 41.79968  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 8
# extent      : -120.167, -120.1244, 41.44378, 41.49685  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 28
# extent      : -123.9392, -120.167, 40.72467, 41.44378  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 3
# extent      : -124.0336, -124.0336, 40.52137, 40.52137  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -122.2406, -122.2406, 37.76528, 37.76528  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 13
# extent      : -122.4947, -118.0519, 34.16167, 37.80444  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 20
# extent      : -121.5144, -118.0519, 34.16167, 37.63015  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 285
# extent      : -123.5909, -117.8365, 34.05358, 39.265  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 128
# extent      : -124.1397, -118.0519, 34.16167, 40.5475  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 237
# extent      : -124.4973, -118.0223, 34.16167, 44.06568  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 133
# extent      : -122.6092, -116.2007, 34.16167, 40.61026  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 23
# extent      : -122.3211, -116.4551, 32.98995, 41.31987  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 133
# extent      : -122.7018, -117.8558, 34.17126, 45.59456  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 40
# extent      : -122.3906, -121.8982, 36.59949, 40.58667  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 3
# extent      : -120.92, -118.1494, 34.11611, 38.40847  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 30
# extent      : -121.9067, -120.0964, 35.11314, 39.22806  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 20
# extent      : -121.5561, -118.3076, 34.96946, 39.5701  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 49
# extent      : -122.5447, -118.2895, 36.7744, 40.04492  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 49
# extent      : -122.6125, -116.2161, 33.74615, 40.44068  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 3
# extent      : -122.1978, -122.1978, 40.98028, 40.98028  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -123.0089, -123.0089, 38.4651, 38.4651  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 2
# extent      : -116.7383, -116.7383, 33.10833, 33.10833  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -122.5225, -122.5225, 37.89083, 37.89083  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 15
# extent      : -122.2988, -122.2988, 38.2683, 38.2683  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 46
# extent      : -122.4908, -119.3569, 33.95, 39.83282  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 67
# extent      : -122.9119, -114.5138, 35.01785, 38.10091  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 30
# extent      : -123.5284, -122.9119, 38.10091, 38.76653  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 56
# extent      : -123.5284, -115.4376, 34.19667, 40.70159  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 82
# extent      : -123.3526, -114.5138, 37.61468, 39.95151  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 7
# extent      : -122.4868, -119.806, 37.85654, 39.5107  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -119.806, -119.806, 39.5107, 39.5107  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 2
# extent      : -117.2785, -117.2785, 34.54633, 34.54633  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 16
# extent      : -122.2378, -117.3, 34.43097, 37.8836  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 9
# extent      : -119.7714, -117.0992, 32.67811, 36.74778  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -122.7031, -122.7031, 41.065, 41.065  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 2
# extent      : -122.164, -122.164, 44.1751, 44.1751  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 3
# extent      : -122.1758, -116.164, 37.79014, 43.63217  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -122.4947, -122.4947, 37.72083, 37.72083  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -120.4389, -120.4389, 37.52064, 37.52064  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -117.8867, -117.8867, 34.08931, 34.08931  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 2
# extent      : -118.2197, -118.2197, 35.69028, 35.69028  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 39
# extent      : -120.2913, -116.4821, 32.60307, 38.70656  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 71
# extent      : -120.1426, -116.4821, 32.60307, 42.974  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 20
# extent      : -119.988, -118.4426, 34.10986, 39.51825  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 30
# extent      : -122.0228, -118.159, 34.42915, 43.5416  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 3
# extent      : -118.4966, -117.9286, 34.14757, 34.19536  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 14
# extent      : -119.9006, -117.7546, 34.18527, 37.92105  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 2
# extent      : -118.6487, -118.6487, 34.15346, 34.15346  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 2
# extent      : -117.8606, -117.8606, 34.19207, 34.19207  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 12
# extent      : -122.1692, -118.4836, 34.18966, 37.42722  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 16
# extent      : -118.5417, -116.471, 32.6059, 34.45835  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 14
# extent      : -121.3217, -116.913, 32.8584, 36.42538  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 5
# extent      : -119.1418, -118.4836, 34.37806, 37.99044  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 66
# extent      : -120.6225, -117.036, 32.9628, 43.7446  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 15
# extent      : -118.9112, -116.1996, 36.78608, 43.6177  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 12
# extent      : -119.7601, -116.719, 33.74005, 36.7928  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 2
# extent      : -119.4641, -119.4641, 36.7166, 36.7166  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -121.7402, -121.7402, 37.21651, 37.21651  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 37
# extent      : -122.5097, -120.7101, 35.58499, 38.34889  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 70
# extent      : -120.6607, -117.0301, 35.15418, 36.20634  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 69
# extent      : -117.5466, -116.7053, 33.66139, 36.54828  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 69
# extent      : -123.0164, -118.1705, 37.33884, 45.7276  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 9
# extent      : -120.954, -117.7546, 34.10667, 46.4234  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -118.371, -118.371, 34.1592, 34.1592  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -118.371, -118.371, 34.1592, 34.1592  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 11
# extent      : -121.5388, -118.3496, 34.13996, 36.8454  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 57
# extent      : -124.0595, -117.682, 33.61471, 40.53769  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 40
# extent      : -122.3162, -118.0406, 34.13996, 40.97192  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 15
# extent      : -123.6481, -117.7546, 34.13996, 42.17181  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 39
# extent      : -123.5845, -120.217, 36.49077, 48.3354  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 12
# extent      : -121.486, -116.164, 34.19, 48.1871  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 2
# extent      : -120.8501, -120.8501, 35.36691, 35.36691  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -121.3185, -121.3185, 35.76441, 35.76441  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -121.0284, -121.0284, 36.13013, 36.13013  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -121.9856, -121.9856, 37.10833, 37.10833  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 22
# extent      : -123.3517, -118.3166, 33.71588, 39.71389  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 4
# extent      : -121.4235, -116.1208, 35.96977, 46.1088  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 3
# extent      : -121.4821, -121.4213, 36.14444, 36.23626  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -118.371, -118.371, 34.1592, 34.1592  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -119.5094, -119.5094, 37.22918, 37.22918  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 2
# extent      : -122.1689, -119.5094, 37.22918, 37.81082  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 5
# extent      : -121.995, -117.3296, 34.56257, 41.42383  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 8
# extent      : -119.3092, -116.4681, 32.60639, 41.269  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -120.1124, -120.1124, 37.7562, 37.7562  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -123.3657, -123.3657, 39.26759, 39.26759  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -122.2342, -122.2342, 37.38417, 37.38417  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 28
# extent      : -118.9454, -116.1865, 34.3883, 43.70362  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 16
# extent      : -119.8402, -112.437, 33.74, 43.81227  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 3
# extent      : -116.166, -112.5821, 38.60064, 43.81227  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 5
# extent      : -118.3202, -116.1371, 34.0892, 43.62333  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 3
# extent      : -122.1692, -121.7033, 37.19667, 37.42722  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 2
# extent      : -122.2528, -122.2528, 37.43, 37.43  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 2
# extent      : -121.4005, -116.6027, 36.85251, 43.34055  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 8
# extent      : -123.3244, -116.3655, 37.42722, 43.14017  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 3
# extent      : -120.1383, -116.317, 35.38493, 43.9716  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 8
# extent      : -119.8784, -116.53, 37.81543, 43.2999  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 58
# extent      : -119.85, -119.4583, 37.00972, 37.83083  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 11
# extent      : -119.6007, -119.6007, 39.95162, 39.95162  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 4
# extent      : -118.8252, -118.8252, 35.10077, 35.10077  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 165
# extent      : -122.4336, -116.4681, 31.80279, 38.58025  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 65
# extent      : -117.0006, -116.2322, 31.2334, 32.40169  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 16
# extent      : -124.0595, -116.4921, 32.73589, 40.53769  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -118.5056, -118.5056, 34.38286, 34.38286  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 5
# extent      : -116.876, -116.615, 32.77361, 33.9256  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 12
# extent      : -122.2252, -116.7806, 32.64417, 40.3146  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 8
# extent      : -119.6387, -116.876, 33.9256, 39.95222  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 2
# extent      : -119.6007, -116.615, 32.85278, 39.95162  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -116.876, -116.876, 33.9256, 33.9256  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 3
# extent      : -117.2431, -117.2426, 33.20004, 33.20515  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 11
# extent      : -116.7806, -116.4388, 32.64417, 32.8536  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 15
# extent      : -118.2599, -116.7806, 32.64417, 34.26996  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 5
# extent      : -116.7806, -115.75, 31.01667, 32.85278  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 3
# extent      : -118.2403, -116.5566, 32.84906, 34.0526  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 16
# extent      : -119.71, -116.4388, 32.67833, 34.46994  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 7
# extent      : -119.76, -116.3015, 34.04, 40.6505  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -115.75, -115.75, 31.01667, 31.01667  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 9
# extent      : -115.75, -115.75, 31.01667, 31.01667  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -115.6167, -115.6167, 31.01667, 31.01667  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 6
# extent      : -116.857, -116.6953, 32.64425, 32.84181  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 3
# extent      : -116.7814, -116.7814, 32.64425, 32.64425  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 36
# extent      : -123.0461, -115.75, 31.01667, 43.297  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 10
# extent      : -121.8823, -115.2461, 33.37045, 43.45711  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -119.3049, -119.3049, 37.14794, 37.14794  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 4
# extent      : -121.4818, -115.9042, 41.87178, 43.66  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -116.876, -116.876, 33.9256, 33.9256  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 3
# extent      : -115.9072, -115.9072, 32.05333, 32.05333  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 4
# extent      : -120.1481, -116.8085, 33.04167, 35.77453  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 14
# extent      : -118.006, -116.4258, 32.98083, 37.82376  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 2
# extent      : -115.5106, -115.5106, 40.16985, 40.16985  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 4
# extent      : -122.5998, -115.5106, 37.87403, 41.87178  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -116.5292, -116.5292, 32.82147, 32.82147  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -121.5553, -121.5553, 39.51389, 39.51389  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 46
# extent      : -122.2411, -116.1897, 32.61766, 40.4347  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -115.5106, -115.5106, 40.16985, 40.16985  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 35
# extent      : -120.7183, -112.17, 32.80428, 43.95698  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 53
# extent      : -120.4617, -116.4229, 32.72812, 40.92432  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 44
# extent      : -119.8223, -117.1469, 32.73164, 40.01372  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -118.6475, -118.6475, 34.15352, 34.15352  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 4
# extent      : -122.3078, -116.719, 32.77333, 37.41056  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 20
# extent      : -120.9042, -116.7271, 32.67778, 36.02056  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 27
# extent      : -117.1228, -116.5474, 32.53448, 32.78975  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 15
# extent      : -123.2616, -114.2806, 32.67778, 44.56535  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 27
# extent      : -118.3751, -115.6945, 33.74005, 37.25458  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 14
# extent      : -116.9539, -116.7271, 32.67778, 33.09171  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 17
# extent      : -117.1106, -116.9193, 32.78496, 32.97465  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 6
# extent      : -119.0601, -116.6739, 32.78975, 34.1475  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 20
# extent      : -122.305, -116.8646, 32.80428, 38.00454  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 40
# extent      : -117.2751, -116.1897, 32.61766, 44.47119  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 44
# extent      : -118.621, -116.6739, 32.53448, 39.25541  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 6
# extent      : -121.782, -116.4529, 32.85839, 42.2249  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 3
# extent      : -122.5881, -118.9135, 34.40043, 37.92703  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 2
# extent      : -122.0832, -122.0832, 37.09166, 37.09166  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -117.8624, -117.8624, 34.19051, 34.19051  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 12
# extent      : -122.23, -116.9707, 32.78496, 37.99726  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 21
# extent      : -123.486, -117.8346, 34.05476, 39.68613  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 16
# extent      : -121.8803, -116.0728, 35.89417, 37.95791  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 32
# extent      : -119.9727, -114.5117, 34.02124, 39.25122  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 15
# extent      : -122.6378, -116.6011, 33.07862, 45.5346  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 101
# extent      : -118.9293, -117.4802, 34.23057, 35.68812  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 7
# extent      : -120.6507, -116.0583, 31.265, 37.64428  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -123.2081, -123.2081, 41.84087, 41.84087  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 2
# extent      : -116.8198, -116.8198, 32.91478, 32.91478  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 4
# extent      : -118.1608, -118.1608, 34.11175, 34.11175  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 5
# extent      : -123.4653, -117.0223, 34.45075, 40.40463  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 21
# extent      : -123.5025, -116.4853, 32.56988, 40.44961  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 13
# extent      : -123.4795, -117.2751, 34.87594, 40.4249  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 51
# extent      : -123.4125, -115.0076, 34.32145, 40.41612  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 28
# extent      : -121.3242, -116.492, 32.77147, 45.49204  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 21
# extent      : -123.0456, -115.4796, 34.58616, 42.19276  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -122.215, -122.215, 38.05393, 38.05393  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 16
# extent      : -122.1692, -115.8775, 32.28793, 37.42722  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 32
# extent      : -123.306, -115.78, 31.38833, 40.23351  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 81
# extent      : -124.3945, -115.8817, 32.28793, 42.51585  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 22
# extent      : -122.2278, -112.29, 32.88433, 40.74  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 11
# extent      : -122.2293, -118.0595, 34.18306, 37.8218  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -121.9684, -121.9684, 39.54185, 39.54185  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 13
# extent      : -122.6008, -116.6011, 33.07862, 39.37481  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -122.9895, -122.9895, 45.52305, 45.52305  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 5
# extent      : -117.2373, -117.0359, 32.96282, 36.11776  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 9
# extent      : -122.9915, -116.617, 32.85326, 42.27756  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 10
# extent      : -121.5238, -113.88, 32.82636, 39.73  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 6
# extent      : -119.9333, -116.9261, 32.90838, 39.6  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 24
# extent      : -121.2542, -113.42, 32.81599, 44.27255  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 5
# extent      : -121.996, -112.57, 32.96551, 42.7046  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -119.5335, -119.5335, 38.68263, 38.68263  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -115.8817, -115.8817, 32.28793, 32.28793  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 3
# extent      : -118.8352, -118.8352, 36.48837, 36.48837  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 2
# extent      : -120.2696, -118.8816, 36.1375, 36.50124  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 7
# extent      : -120.2695, -118.8352, 34.36817, 36.48837  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 2
# extent      : -121.2163, -121.2163, 37.06543, 37.06543  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 40
# extent      : -124.2948, -114.75, 31.52167, 42.50414  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 18
# extent      : -123.4824, -113.5612, 34.27391, 42.30613  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 7
# extent      : -123.6263, -114.0706, 37.51032, 41.9953  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 30
# extent      : -118.8959, -115.5433, 33.04176, 36.55104  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 8
# extent      : -122.4309, -116.617, 32.85326, 38.47242  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -121.8692, -121.8692, 36.49424, 36.49424  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 25
# extent      : -121.0519, -112.4164, 32.28793, 40.59981  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 11
# extent      : -121.0519, -116.1101, 36.35559, 39.51264  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 55
# extent      : -120.802, -118.2471, 34.1235, 40.7987  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 35
# extent      : -122.3666, -116.8614, 34.1728, 40.27816  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 6
# extent      : -122.1692, -119.1443, 37.42722, 38.00016  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 3
# extent      : -119.6485, -116.8614, 34.1728, 39.31015  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -122.2834, -122.2834, 37.92903, 37.92903  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 23
# extent      : -122.2404, -120.2106, 37.87674, 47.9204  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 30
# extent      : -122.6026, -119.5741, 37.40808, 47.1698  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 9
# extent      : -120.476, -114.0395, 32.87372, 48.0442  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 17
# extent      : -122.5897, -116.8721, 36.54417, 47.42334  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 8
# extent      : -122.6856, -118.4036, 36.14249, 48.179  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 17
# extent      : -123.39, -118.3656, 37.16622, 45.09  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 11
# extent      : -122.4782, -122.2834, 37.92903, 47.429  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 13
# extent      : -122.365, -122.365, 37.58416, 37.58416  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 6
# extent      : -123.486, -120.0165, 37.8978, 47.841  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 45
# extent      : -123.2918, -116.6732, 33.87577, 47.1565  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 71
# extent      : -121.8645, -115.3729, 32.93404, 39.20347  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 23
# extent      : -120.9552, -112.602, 35.15996, 44.47066  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 4
# extent      : -121.846, -117.2006, 33.36129, 45.70678  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 16
# extent      : -122.8037, -116.4664, 32.1138, 47.3507  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 16
# extent      : -122.2377, -116.75, 34.08772, 46.0151  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -114.1333, -114.1333, 36.783, 36.783  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 8
# extent      : -121.0759, -121.0203, 38.67156, 38.71505  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 4
# extent      : -122.4102, -117.6608, 33.49279, 37.5772  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 34
# extent      : -122.4102, -121.8812, 37.5772, 37.96631  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 11
# extent      : -122.6885, -118.2418, 35.68546, 47.2115  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 38
# extent      : -122.6885, -116.6553, 34.0966, 47.3639  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 52
# extent      : -122.4032, -115.5747, 33.73473, 47.5412  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 55
# extent      : -122.7954, -115.4333, 32.365, 46.0151  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 19
# extent      : -124.06, -115.783, 34.69484, 45.63534  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 21
# extent      : -124.3392, -114.2806, 36.42993, 47.2529  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 6
# extent      : -123.1059, -121.1787, 44.6365, 47.27426  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -122.3624, -122.3624, 38.2499, 38.2499  (xmin, xmax, ymin, ymax)
# coord. ref. : NA
# class       : SpatialPoints
# features    : 1
# extent      : -121.9234, -121.9234, 36.55263, 36.55263  (xmin, xmax, ymin, ymax)
# coord. ref. : NA

# %%
ans
# Out:
#     year month structure.9.64999961853027...Names....value..
# 1   1900  5    9.65
# 2   1901  4      NA
# 3   1901  7      NA
# 4   1901  9      NA
# 5   1902  7      NA
# 6   1902  8      NA
# 7   1902 10      NA
# 8   1902 11      NA
# 9   1903  3      NA
# 10  1903  4      NA
# 11  1903  5      NA
# 12  1903  7      NA
# 13  1903  8      NA
# 14  1903  9      NA
# 15  1904  3      NA
# 16  1904  4      NA
# 17  1904  5      NA
# 18  1904  6      NA
# 19  1904  7    9.65
# 20  1904  8      NA
# 21  1904  9      NA
# 22  1905  4      NA
# 23  1905  6      NA
# 24  1905  7      NA
# 25  1905  8      NA
# 26  1906  3      NA
# 27  1906  6      NA
# 28  1906  8      NA
# 29  1906  9      NA
# 30  1906 12      NA
# ⋮   ⋮    ⋮     ⋮
# 260 1936 10    NA
# 261 1937  3    NA
# 262 1937  4    NA
# 263 1937  5    NA
# 264 1937  6    NA
# 265 1937  7    NA
# 266 1937  8    NA
# 267 1937  9    NA
# 268 1937 10    NA
# 269 1938  2    NA
# 270 1938  3    NA
# 271 1938  4    NA
# 272 1938  5    NA
# 273 1938  6    NA
# 274 1938  7    NA
# 275 1938  8    NA
# 276 1938  9    NA
# 277 1938 10    NA
# 278 1938 11    NA
# 279 1939  1    NA
# 280 1939  2    NA
# 281 1939  3    NA
# 282 1939  4    NA
# 283 1939  5    NA
# 284 1939  6    NA
# 285 1939  7    NA
# 286 1939  8    NA
# 287 1939  9    NA
# 288 1939 10    NA
# 289 1939 11    NA
#     structure.9.64999961853027...Names....value...1
# 1   9.65
# 2     NA
# 3     NA
# 4     NA
# 5     NA
# 6     NA
# 7     NA
# 8     NA
# 9     NA
# 10    NA
# 11    NA
# 12    NA
# 13    NA
# 14    NA
# 15    NA
# 16    NA
# 17    NA
# 18    NA
# 19  9.65
# 20    NA
# 21    NA
# 22    NA
# 23    NA
# 24    NA
# 25    NA
# 26    NA
# 27    NA
# 28    NA
# 29    NA
# 30    NA
# ⋮   ⋮
# 260 NA
# 261 NA
# 262 NA
# 263 NA
# 264 NA
# 265 NA
# 266 NA
# 267 NA
# 268 NA
# 269 NA
# 270 NA
# 271 NA
# 272 NA
# 273 NA
# 274 NA
# 275 NA
# 276 NA
# 277 NA
# 278 NA
# 279 NA
# 280 NA
# 281 NA
# 282 NA
# 283 NA
# 284 NA
# 285 NA
# 286 NA
# 287 NA
# 288 NA
# 289 NA
#     structure.9.64999961853027...Names....value...2
# 1   9.65
# 2     NA
# 3     NA
# 4     NA
# 5     NA
# 6     NA
# 7     NA
# 8     NA
# 9     NA
# 10    NA
# 11    NA
# 12    NA
# 13    NA
# 14    NA
# 15    NA
# 16    NA
# 17    NA
# 18    NA
# 19  9.65
# 20    NA
# 21    NA
# 22    NA
# 23    NA
# 24    NA
# 25    NA
# 26    NA
# 27    NA
# 28    NA
# 29    NA
# 30    NA
# ⋮   ⋮
# 260 NA
# 261 NA
# 262 NA
# 263 NA
# 264 NA
# 265 NA
# 266 NA
# 267 NA
# 268 NA
# 269 NA
# 270 NA
# 271 NA
# 272 NA
# 273 NA
# 274 NA
# 275 NA
# 276 NA
# 277 NA
# 278 NA
# 279 NA
# 280 NA
# 281 NA
# 282 NA
# 283 NA
# 284 NA
# 285 NA
# 286 NA
# 287 NA
# 288 NA
# 289 NA
#     structure.9.64999961853027...Names....value...3
# 1   9.65
# 2     NA
# 3     NA
# 4     NA
# 5     NA
# 6     NA
# 7     NA
# 8     NA
# 9     NA
# 10    NA
# 11    NA
# 12    NA
# 13    NA
# 14    NA
# 15    NA
# 16    NA
# 17    NA
# 18    NA
# 19  9.65
# 20    NA
# 21    NA
# 22    NA
# 23    NA
# 24    NA
# 25    NA
# 26    NA
# 27    NA
# 28    NA
# 29    NA
# 30    NA
# ⋮   ⋮
# 260 NA
# 261 NA
# 262 NA
# 263 NA
# 264 NA
# 265 NA
# 266 NA
# 267 NA
# 268 NA
# 269 NA
# 270 NA
# 271 NA
# 272 NA
# 273 NA
# 274 NA
# 275 NA
# 276 NA
# 277 NA
# 278 NA
# 279 NA
# 280 NA
# 281 NA
# 282 NA
# 283 NA
# 284 NA
# 285 NA
# 286 NA
# 287 NA
# 288 NA
# 289 NA
#     structure.9.64999961853027...Names....value...4
# 1   9.65
# 2     NA
# 3     NA
# 4     NA
# 5     NA
# 6     NA
# 7     NA
# 8     NA
# 9     NA
# 10    NA
# 11    NA
# 12    NA
# 13    NA
# 14    NA
# 15    NA
# 16    NA
# 17    NA
# 18    NA
# 19  9.65
# 20    NA
# 21    NA
# 22    NA
# 23    NA
# 24    NA
# 25    NA
# 26    NA
# 27    NA
# 28    NA
# 29    NA
# 30    NA
# ⋮   ⋮
# 260 NA
# 261 NA
# 262 NA
# 263 NA
# 264 NA
# 265 NA
# 266 NA
# 267 NA
# 268 NA
# 269 NA
# 270 NA
# 271 NA
# 272 NA
# 273 NA
# 274 NA
# 275 NA
# 276 NA
# 277 NA
# 278 NA
# 279 NA
# 280 NA
# 281 NA
# 282 NA
# 283 NA
# 284 NA
# 285 NA
# 286 NA
# 287 NA
# 288 NA
# 289 NA
#     structure.9.64999961853027...Names....value...5
# 1   9.65
# 2     NA
# 3     NA
# 4     NA
# 5     NA
# 6     NA
# 7     NA
# 8     NA
# 9     NA
# 10    NA
# 11    NA
# 12    NA
# 13    NA
# 14    NA
# 15    NA
# 16    NA
# 17    NA
# 18    NA
# 19  9.65
# 20    NA
# 21    NA
# 22    NA
# 23    NA
# 24    NA
# 25    NA
# 26    NA
# 27    NA
# 28    NA
# 29    NA
# 30    NA
# ⋮   ⋮
# 260 NA
# 261 NA
# 262 NA
# 263 NA
# 264 NA
# 265 NA
# 266 NA
# 267 NA
# 268 NA
# 269 NA
# 270 NA
# 271 NA
# 272 NA
# 273 NA
# 274 NA
# 275 NA
# 276 NA
# 277 NA
# 278 NA
# 279 NA
# 280 NA
# 281 NA
# 282 NA
# 283 NA
# 284 NA
# 285 NA
# 286 NA
# 287 NA
# 288 NA
# 289 NA
#     structure.9.64999961853027...Names....value...6
# 1   9.65
# 2     NA
# 3     NA
# 4     NA
# 5     NA
# 6     NA
# 7     NA
# 8     NA
# 9     NA
# 10    NA
# 11    NA
# 12    NA
# 13    NA
# 14    NA
# 15    NA
# 16    NA
# 17    NA
# 18    NA
# 19  9.65
# 20    NA
# 21    NA
# 22    NA
# 23    NA
# 24    NA
# 25    NA
# 26    NA
# 27    NA
# 28    NA
# 29    NA
# 30    NA
# ⋮   ⋮
# 260 NA
# 261 NA
# 262 NA
# 263 NA
# 264 NA
# 265 NA
# 266 NA
# 267 NA
# 268 NA
# 269 NA
# 270 NA
# 271 NA
# 272 NA
# 273 NA
# 274 NA
# 275 NA
# 276 NA
# 277 NA
# 278 NA
# 279 NA
# 280 NA
# 281 NA
# 282 NA
# 283 NA
# 284 NA
# 285 NA
# 286 NA
# 287 NA
# 288 NA
# 289 NA
#     structure.9.64999961853027...Names....value...7 ⋯
# 1   9.65                                            ⋯
# 2     NA                                            ⋯
# 3     NA                                            ⋯
# 4     NA                                            ⋯
# 5     NA                                            ⋯
# 6     NA                                            ⋯
# 7     NA                                            ⋯
# 8     NA                                            ⋯
# 9     NA                                            ⋯
# 10    NA                                            ⋯
# 11    NA                                            ⋯
# 12    NA                                            ⋯
# 13    NA                                            ⋯
# 14    NA                                            ⋯
# 15    NA                                            ⋯
# 16    NA                                            ⋯
# 17    NA                                            ⋯
# 18    NA                                            ⋯
# 19  9.65                                            ⋯
# 20    NA                                            ⋯
# 21    NA                                            ⋯
# 22    NA                                            ⋯
# 23    NA                                            ⋯
# 24    NA                                            ⋯
# 25    NA                                            ⋯
# 26    NA                                            ⋯
# 27    NA                                            ⋯
# 28    NA                                            ⋯
# 29    NA                                            ⋯
# 30    NA                                            ⋯
# ⋮   ⋮                                               ⋱
# 260 NA                                              ⋯
# 261 NA                                              ⋯
# 262 NA                                              ⋯
# 263 NA                                              ⋯
# 264 NA                                              ⋯
# 265 NA                                              ⋯
# 266 NA                                              ⋯
# 267 NA                                              ⋯
# 268 NA                                              ⋯
# 269 NA                                              ⋯
# 270 NA                                              ⋯
# 271 NA                                              ⋯
# 272 NA                                              ⋯
# 273 NA                                              ⋯
# 274 NA                                              ⋯
# 275 NA                                              ⋯
# 276 NA                                              ⋯
# 277 NA                                              ⋯
# 278 NA                                              ⋯
# 279 NA                                              ⋯
# 280 NA                                              ⋯
# 281 NA                                              ⋯
# 282 NA                                              ⋯
# 283 NA                                              ⋯
# 284 NA                                              ⋯
# 285 NA                                              ⋯
# 286 NA                                              ⋯
# 287 NA                                              ⋯
# 288 NA                                              ⋯
# 289 NA                                              ⋯
#     structure.8.85000038146973...Names....value...4
# 1   NA
# 2   NA
# 3   NA
# 4   NA
# 5   NA
# 6   NA
# 7   NA
# 8   NA
# 9   NA
# 10  NA
# 11  NA
# 12  NA
# 13  NA
# 14  NA
# 15  NA
# 16  NA
# 17  NA
# 18  NA
# 19  NA
# 20  NA
# 21  NA
# 22  NA
# 23  NA
# 24  NA
# 25  NA
# 26  NA
# 27  NA
# 28  NA
# 29  NA
# 30  NA
# ⋮   ⋮
# 260   NA
# 261   NA
# 262   NA
# 263   NA
# 264   NA
# 265   NA
# 266   NA
# 267   NA
# 268   NA
# 269   NA
# 270   NA
# 271   NA
# 272   NA
# 273   NA
# 274   NA
# 275   NA
# 276   NA
# 277   NA
# 278   NA
# 279   NA
# 280   NA
# 281   NA
# 282   NA
# 283   NA
# 284   NA
# 285   NA
# 286 8.85
# 287   NA
# 288   NA
# 289   NA
#     structure.8.85000038146973...Names....value...5
# 1   NA
# 2   NA
# 3   NA
# 4   NA
# 5   NA
# 6   NA
# 7   NA
# 8   NA
# 9   NA
# 10  NA
# 11  NA
# 12  NA
# 13  NA
# 14  NA
# 15  NA
# 16  NA
# 17  NA
# 18  NA
# 19  NA
# 20  NA
# 21  NA
# 22  NA
# 23  NA
# 24  NA
# 25  NA
# 26  NA
# 27  NA
# 28  NA
# 29  NA
# 30  NA
# ⋮   ⋮
# 260   NA
# 261   NA
# 262   NA
# 263   NA
# 264   NA
# 265   NA
# 266   NA
# 267   NA
# 268   NA
# 269   NA
# 270   NA
# 271   NA
# 272   NA
# 273   NA
# 274   NA
# 275   NA
# 276   NA
# 277   NA
# 278   NA
# 279   NA
# 280   NA
# 281   NA
# 282   NA
# 283   NA
# 284   NA
# 285   NA
# 286 8.85
# 287   NA
# 288   NA
# 289   NA
#     structure.6.3899998664856...Names....value...1
# 1   NA
# 2   NA
# 3   NA
# 4   NA
# 5   NA
# 6   NA
# 7   NA
# 8   NA
# 9   NA
# 10  NA
# 11  NA
# 12  NA
# 13  NA
# 14  NA
# 15  NA
# 16  NA
# 17  NA
# 18  NA
# 19  NA
# 20  NA
# 21  NA
# 22  NA
# 23  NA
# 24  NA
# 25  NA
# 26  NA
# 27  NA
# 28  NA
# 29  NA
# 30  NA
# ⋮   ⋮
# 260   NA
# 261   NA
# 262   NA
# 263   NA
# 264   NA
# 265   NA
# 266   NA
# 267   NA
# 268   NA
# 269   NA
# 270   NA
# 271   NA
# 272   NA
# 273   NA
# 274   NA
# 275   NA
# 276   NA
# 277   NA
# 278   NA
# 279   NA
# 280   NA
# 281   NA
# 282   NA
# 283   NA
# 284   NA
# 285   NA
# 286 6.39
# 287   NA
# 288   NA
# 289   NA
#     structure.8.85000038146973...Names....value...6
# 1   NA
# 2   NA
# 3   NA
# 4   NA
# 5   NA
# 6   NA
# 7   NA
# 8   NA
# 9   NA
# 10  NA
# 11  NA
# 12  NA
# 13  NA
# 14  NA
# 15  NA
# 16  NA
# 17  NA
# 18  NA
# 19  NA
# 20  NA
# 21  NA
# 22  NA
# 23  NA
# 24  NA
# 25  NA
# 26  NA
# 27  NA
# 28  NA
# 29  NA
# 30  NA
# ⋮   ⋮
# 260   NA
# 261   NA
# 262   NA
# 263   NA
# 264   NA
# 265   NA
# 266   NA
# 267   NA
# 268   NA
# 269   NA
# 270   NA
# 271   NA
# 272   NA
# 273   NA
# 274   NA
# 275   NA
# 276   NA
# 277   NA
# 278   NA
# 279   NA
# 280   NA
# 281   NA
# 282   NA
# 283   NA
# 284   NA
# 285   NA
# 286 8.85
# 287   NA
# 288   NA
# 289   NA
#     structure.11.1899995803833...Names....value...1
# 1   NA
# 2   NA
# 3   NA
# 4   NA
# 5   NA
# 6   NA
# 7   NA
# 8   NA
# 9   NA
# 10  NA
# 11  NA
# 12  NA
# 13  NA
# 14  NA
# 15  NA
# 16  NA
# 17  NA
# 18  NA
# 19  NA
# 20  NA
# 21  NA
# 22  NA
# 23  NA
# 24  NA
# 25  NA
# 26  NA
# 27  NA
# 28  NA
# 29  NA
# 30  NA
# ⋮   ⋮
# 260    NA
# 261    NA
# 262    NA
# 263    NA
# 264    NA
# 265    NA
# 266    NA
# 267    NA
# 268    NA
# 269    NA
# 270    NA
# 271    NA
# 272    NA
# 273    NA
# 274    NA
# 275    NA
# 276    NA
# 277    NA
# 278    NA
# 279    NA
# 280    NA
# 281    NA
# 282    NA
# 283    NA
# 284    NA
# 285    NA
# 286 11.19
# 287    NA
# 288    NA
# 289    NA
#     structure.11.1899995803833...Names....value...2
# 1   NA
# 2   NA
# 3   NA
# 4   NA
# 5   NA
# 6   NA
# 7   NA
# 8   NA
# 9   NA
# 10  NA
# 11  NA
# 12  NA
# 13  NA
# 14  NA
# 15  NA
# 16  NA
# 17  NA
# 18  NA
# 19  NA
# 20  NA
# 21  NA
# 22  NA
# 23  NA
# 24  NA
# 25  NA
# 26  NA
# 27  NA
# 28  NA
# 29  NA
# 30  NA
# ⋮   ⋮
# 260    NA
# 261    NA
# 262    NA
# 263    NA
# 264    NA
# 265    NA
# 266    NA
# 267    NA
# 268    NA
# 269    NA
# 270    NA
# 271    NA
# 272    NA
# 273    NA
# 274    NA
# 275    NA
# 276    NA
# 277    NA
# 278    NA
# 279    NA
# 280    NA
# 281    NA
# 282    NA
# 283    NA
# 284    NA
# 285    NA
# 286 11.19
# 287    NA
# 288    NA
# 289    NA
#     structure.15.1800003051758...Names....value..
# 1   NA
# 2   NA
# 3   NA
# 4   NA
# 5   NA
# 6   NA
# 7   NA
# 8   NA
# 9   NA
# 10  NA
# 11  NA
# 12  NA
# 13  NA
# 14  NA
# 15  NA
# 16  NA
# 17  NA
# 18  NA
# 19  NA
# 20  NA
# 21  NA
# 22  NA
# 23  NA
# 24  NA
# 25  NA
# 26  NA
# 27  NA
# 28  NA
# 29  NA
# 30  NA
# ⋮   ⋮
# 260    NA
# 261    NA
# 262    NA
# 263    NA
# 264    NA
# 265    NA
# 266    NA
# 267    NA
# 268    NA
# 269    NA
# 270    NA
# 271    NA
# 272    NA
# 273    NA
# 274    NA
# 275    NA
# 276    NA
# 277    NA
# 278    NA
# 279    NA
# 280    NA
# 281    NA
# 282    NA
# 283    NA
# 284    NA
# 285    NA
# 286 15.18
# 287    NA
# 288    NA
# 289    NA
#     structure.9.57999992370605...Names....value..
# 1   NA
# 2   NA
# 3   NA
# 4   NA
# 5   NA
# 6   NA
# 7   NA
# 8   NA
# 9   NA
# 10  NA
# 11  NA
# 12  NA
# 13  NA
# 14  NA
# 15  NA
# 16  NA
# 17  NA
# 18  NA
# 19  NA
# 20  NA
# 21  NA
# 22  NA
# 23  NA
# 24  NA
# 25  NA
# 26  NA
# 27  NA
# 28  NA
# 29  NA
# 30  NA
# ⋮   ⋮
# 260   NA
# 261   NA
# 262   NA
# 263   NA
# 264   NA
# 265   NA
# 266   NA
# 267   NA
# 268   NA
# 269   NA
# 270   NA
# 271   NA
# 272   NA
# 273   NA
# 274   NA
# 275   NA
# 276   NA
# 277   NA
# 278   NA
# 279   NA
# 280   NA
# 281   NA
# 282   NA
# 283   NA
# 284   NA
# 285   NA
# 286 9.58
# 287   NA
# 288   NA
# 289   NA
#     structure.11.6000003814697...Names....value..
# 1   NA
# 2   NA
# 3   NA
# 4   NA
# 5   NA
# 6   NA
# 7   NA
# 8   NA
# 9   NA
# 10  NA
# 11  NA
# 12  NA
# 13  NA
# 14  NA
# 15  NA
# 16  NA
# 17  NA
# 18  NA
# 19  NA
# 20  NA
# 21  NA
# 22  NA
# 23  NA
# 24  NA
# 25  NA
# 26  NA
# 27  NA
# 28  NA
# 29  NA
# 30  NA
# ⋮   ⋮
# 260   NA
# 261   NA
# 262   NA
# 263   NA
# 264   NA
# 265   NA
# 266   NA
# 267   NA
# 268   NA
# 269   NA
# 270   NA
# 271   NA
# 272   NA
# 273   NA
# 274   NA
# 275   NA
# 276   NA
# 277   NA
# 278   NA
# 279   NA
# 280   NA
# 281   NA
# 282   NA
# 283   NA
# 284   NA
# 285   NA
# 286 11.6
# 287   NA
# 288   NA
# 289   NA
#     structure.4.25...Names....value..
# 1   NA
# 2   NA
# 3   NA
# 4   NA
# 5   NA
# 6   NA
# 7   NA
# 8   NA
# 9   NA
# 10  NA
# 11  NA
# 12  NA
# 13  NA
# 14  NA
# 15  NA
# 16  NA
# 17  NA
# 18  NA
# 19  NA
# 20  NA
# 21  NA
# 22  NA
# 23  NA
# 24  NA
# 25  NA
# 26  NA
# 27  NA
# 28  NA
# 29  NA
# 30  NA
# ⋮   ⋮
# 260   NA
# 261   NA
# 262   NA
# 263   NA
# 264   NA
# 265   NA
# 266   NA
# 267   NA
# 268   NA
# 269   NA
# 270   NA
# 271   NA
# 272   NA
# 273   NA
# 274   NA
# 275   NA
# 276   NA
# 277   NA
# 278   NA
# 279   NA
# 280   NA
# 281   NA
# 282   NA
# 283   NA
# 284   NA
# 285   NA
# 286   NA
# 287   NA
# 288   NA
# 289 4.25

# %%
a %>% dplyr::select(decimallatitude, decimallongitude, tmin, month, year)
# Out:
#      decimallatitude decimallongitude tmin  month year
# 1    34.36666        -118.2016         9.65 8     1908
# 2    34.10986        -118.5706         9.65 7     1915
# 3    33.83580        -116.9890         9.65 5     1916
# 4    48.30930        -120.6560         9.65 7     1918
# 5    43.29990        -116.5300         9.65 8     1922
# 6    37.22676        -121.6958         9.65 8     1902
# 7    46.42340        -120.9540         9.65 9     1917
# 8    45.72760        -121.4860         9.65 8     1918
# 9    38.01173        -122.7018         9.65 9     1911
# 10   34.45835        -118.5417         9.65 4     1916
# 11   37.68445        -121.9218         9.65 7     1905
# 12   37.83254        -122.4908         9.65 4     1913
# 13   39.95162        -119.6007         9.65 7     1924
# 14   34.10986        -118.5706         9.65 7     1915
# 15   36.63069        -119.0127         9.65 8     1907
# 16   33.83580        -116.9890         9.65 5     1916
# 17   34.45835        -118.5417         9.65 4     1916
# 18   34.18527        -117.7546         9.65 9     1917
# 19   37.83254        -122.4908         2.32 4     1913
# 20   33.66830        -117.7890         2.32 8     1911
# 21   40.98028        -122.1978         8.24 8     1912
# 22   32.85840        -116.9130        -0.75 5     1916
# 23   48.33540        -120.6950        11.18 7     1918
# 24   47.86240        -120.4180        13.52 7     1918
# 25   45.94140        -120.6540        11.27 3     1939
# 26   45.72760        -121.4860        11.97 8     1918
# 27   38.73226        -117.0487         9.53 6     1915
# 28   35.14023        -119.0747        15.34 7     1904
# 29   34.18527        -117.7546        11.27 6     1918
# 30   33.92560        -116.8760         8.20 6     1924
# ⋮    ⋮               ⋮                ⋮     ⋮     ⋮
# 5439 32.85326        -116.6170        11.06 5     1926
# 5440 32.85326        -116.6170        14.35 5     1926
# 5441 32.85326        -116.6170        14.35 5     1926
# 5442 32.82147        -116.5292        11.19 5     1926
# 5443 32.82147        -116.5292        12.45 5     1926
# 5444 32.78975        -116.6739         8.85 5     1926
# 5445 32.85326        -116.6170        13.45 5     1926
# 5446 33.37045        -117.0747         8.85 6     1926
# 5447 33.37045        -117.0747         8.85 6     1926
# 5448 32.82147        -116.5292         8.85 5     1926
# 5449 32.82147        -116.5292         6.39 5     1926
# 5450 32.82147        -116.5292         8.85 5     1926
# 5451 32.82147        -116.5292         8.85 5     1926
# 5452 32.82147        -116.5292         6.39 5     1926
# 5453 32.82147        -116.5292         8.85 5     1926
# 5454 32.82147        -116.5292        11.19 5     1926
# 5455 32.82147        -116.5292        11.19 5     1926
# 5456 32.82147        -116.5292        11.18 5     1926
# 5457 32.82147        -116.5292        10.38 5     1926
# 5458 32.82147        -116.5292        15.18 5     1926
# 5459 32.82147        -116.5292         9.58 5     1926
# 5460 32.64425        -116.7814        11.60 4     1926
# 5461 32.64425        -116.7814         8.96 4     1926
# 5462 32.64425        -116.7814         9.85 4     1926
# 5463 32.64425        -116.7814         9.85 3     1926
# 5464 32.64425        -116.7814        11.80 3     1926
# 5465 32.64425        -116.7814        11.80 3     1926
# 5466 32.67983        -116.8570         9.20 3     1926
# 5467 32.84181        -116.6953         7.35 3     1926
# 5468 32.64425        -116.7814         4.25 3     1926

# %%
colnames(a)
# Out:
#  [1] "gbifid"                        "datasetkey"
#  [3] "occurrenceid"                  "kingdom"
#  [5] "phylum"                        "class"
#  [7] "order"                         "family"
#  [9] "genus"                         "species"
# [11] "infraspecificepithet"          "taxonrank"
# [13] "scientificname"                "countrycode"
# [15] "locality"                      "publishingorgkey"
# [17] "decimallatitude"               "decimallongitude"
# [19] "coordinateuncertaintyinmeters" "coordinateprecision"
# [21] "elevation"                     "elevationaccuracy"
# [23] "depth"                         "depthaccuracy"
# [25] "eventdate"                     "day"
# [27] "month"                         "year"
# [29] "taxonkey"                      "specieskey"
# [31] "basisofrecord"                 "institutioncode"
# [33] "collectioncode"                "catalognumber"
# [35] "recordnumber"                  "identifiedby"
# [37] "license"                       "rightsholder"
# [39] "recordedby"                    "typestatus"
# [41] "establishmentmeans"            "lastinterpreted"
# [43] "mediatype"                     "issue"
# [45] "tmin"
